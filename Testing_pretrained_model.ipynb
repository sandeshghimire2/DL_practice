# %% [markdown]
# <a href="https://colab.research.google.com/github/sandeshghimire2/DL_practice/blob/main/Testing_pretrained_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.applications import VGG16

# %%
model = VGG16(weights="imagenet")

# %%
model.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ...

# %%
from tensorflow.keras.utils import plot_model

plot_model(
    model,
    to_file="model.png",
    show_shapes=True,
    show_layer_names=True
)

# %%
from keras.preprocessing import image

# %%
img = image.load_img("/content/cat.jpeg",target_size=(224,224))

# %%
img_array = image.img_to_array(img)

# %%
img_array_ = img_array.reshape((1,) + img_array.shape)

# %%
pred = model.predict(img_array_)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 766ms/step

# %%
pred
# Out:
# array([[4.82721196e-10, 8.22767277e-09, 1.69126335e-09, 4.85860152e-09,
#         1.21028998e-09, 1.58762319e-08, 1.87232208e-09, 6.97987224e-09,
#         1.09602896e-08, 7.18661797e-09, 3.07861860e-08, 2.47778409e-10,
#         6.99827183e-08, 8.80346036e-08, 4.32639347e-09, 6.12157464e-07,
#         1.83087376e-08, 2.62401301e-07, 4.29160565e-08, 1.51856216e-09,
#         6.26783788e-07, 4.43975789e-09, 2.30126540e-09, 4.09501455e-09,
#         2.82103679e-06, 1.89285387e-09, 2.17968799e-09, 3.20786242e-09,
#         1.44623613e-09, 2.41390063e-09, 9.21417396e-08, 4.18943102e-09,
#         1.62410139e-08, 6.58231636e-10, 1.81183673e-08, 2.98307441e-08,
#         9.94446268e-08, 4.54383269e-08, 1.75255543e-08, 3.09747406e-07,
#         7.98583173e-08, 5.13622581e-07, 2.52053365e-08, 2.64880356e-07,
#         6.17640410e-07, 3.46991613e-09, 5.10297639e-07, 3.51211256e-08,
#         3.15848609e-08, 2.91918969e-08, 3.19630296e-08, 4.19681498e-08,
# ...

# %%
from tensorflow.keras.applications.vgg16 import decode_predictions

result = decode_predictions(pred, top=5)[0]
for i in result:
  print(i[1])
# Out:
# tabby
# Egyptian_cat
# tiger_cat
# lynx
# cougar
